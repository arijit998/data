# %%
import pandas as pd

# %%
import seaborn as sn

# %%
data=pd.read_csv("/content/INFY.NS.csv")

# %%
sn.heatmap(data.isnull())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6501 entries, 0 to 6500
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6501 non-null   datetime64[ns]
#  1   Open       6487 non-null   float64
#  2   High       6501 non-null   float64
#  3   Low        6487 non-null   float64
#  4   Close      6501 non-null   float64
#  5   Adj Close  6487 non-null   float64
#  6   Volume     6487 non-null   float64
#  7   year       6501 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 406.4 KB

# %%
data.isnull().sum()
# Out:
# Date          0
# Open         14
# High          0
# Low          14
# Close         0
# Adj Close    14
# Volume       14
# year          0
# dtype: int64

# %%
data["Close"].fillna(method="PAD",inplace=True)

# %%
a=data["Close"].plot(figsize=(15,8),title="close price")
a.set_xlabel("x-axis")
a.set_ylabel("y-axis")
# Out:
# Text(0, 0.5, 'y-axis')

# %%
data["High"].fillna(data["High"].mean(),inplace=True)

# %%
data["High"].plot(figsize=(15,8))

# %%
data["Date"]=pd.to_datetime(data["Date"])

# %%
data["year"]=data["Date"].dt.year

# %%
data.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close    Volume  \
# 0 1996-01-01  0.794921  0.796679  0.791015  0.796679   0.549483  204800.0
# 1 1996-01-02  0.794921  0.798828  0.793457  0.793457   0.547260  204800.0
# 2 1996-01-03  0.798828  0.798828  0.798828  0.798828   0.550965  102400.0
# 3 1996-01-04  0.791015  0.794921  0.791015  0.793554   0.547327  307200.0
# 4 1996-01-05  0.784179  0.784179  0.784179  0.784179   0.540861   51200.0
#
#    year
# 0  1996
# 1  1996
# 2  1996
# 3  1996
# 4  1996

# %%
data1=data.drop(["Date","Adj Close"],axis=1)

# %%
data1.head()
# Out:
#        Open      High       Low     Close    Volume  year
# 0  0.794921  0.796679  0.791015  0.796679  204800.0  1996
# 1  0.794921  0.798828  0.793457  0.793457  204800.0  1996
# 2  0.798828  0.798828  0.798828  0.798828  102400.0  1996
# 3  0.791015  0.794921  0.791015  0.793554  307200.0  1996
# 4  0.784179  0.784179  0.784179  0.784179   51200.0  1996

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6501 entries, 0 to 6500
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    6501 non-null   float64
#  1   High    6501 non-null   float64
#  2   Low     6501 non-null   float64
#  3   Close   6501 non-null   float64
#  4   Volume  6501 non-null   float64
#  5   year    6501 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 304.9 KB

# %%
data1.isnull().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# year      0
# dtype: int64

# %%
data1["Open"].fillna(data1["Open"].mean(),inplace=True)

# %%
data1["Volume"].fillna(data1["Volume"].mean(),inplace=True)

# %%
data1["Low"].fillna(data1["Low"].mean(),inplace=True)

# %%
data1.head()
# Out:
#        Open      High       Low     Close    Volume  year
# 0  0.794921  0.796679  0.791015  0.796679  204800.0  1996
# 1  0.794921  0.798828  0.793457  0.793457  204800.0  1996
# 2  0.798828  0.798828  0.798828  0.798828  102400.0  1996
# 3  0.791015  0.794921  0.791015  0.793554  307200.0  1996
# 4  0.784179  0.784179  0.784179  0.784179   51200.0  1996

# %%
x=data1.drop("Close",axis=1)

# %%
y=data1["Close"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.15)

# %%
x_train.shape
# Out:
# (5525, 5)

# %%
x_test.shape
# Out:
# (976, 5)

# %%
from sklearn.linear_model import LinearRegression

# %%
a=LinearRegression()

# %%
a.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
z=a.predict(x_test)

# %%
a.score(x,y)
# Out:
# 0.998664721721284
